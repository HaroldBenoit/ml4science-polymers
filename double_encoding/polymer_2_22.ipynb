# %% [markdown]
# # Polymer-2 and Polymer-22 classification
# This notebook contains the code for exploratory data analysis, preprocessing and modelling of the task of distinguishing between 1-bit polymers (with one bulky element) and 2-bit polymers (with two bulky elements)

# %%
# %load_ext autoreload
# %autoreload 2


## classic pydata stack
import os 
import numpy as np
from tqdm import tqdm
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
import statsmodels.formula.api as smf

from sklearn.ensemble import RandomForestClassifier


# %matplotlib inline 

plt.style.use('ggplot')
plt.rcParams['figure.figsize'] = (15,7)


import sys

import vanilla_NN as NN

sys.path.append('..')
from pipeline import *
from models import *

# %% [markdown]
# ## Exploratory Data Analysis
# Let's first dive into the data to get familiar with it and prepare for data processing. We are given 2 numpy files corresponding to 2 different polymer types (AA66266AA and AA662266AA), each file containing a list of sequences/events of *(timestamp, current)* pairs where each sequence represents an event of polymer going through a nanopore. Our data has a temporal nature and hence, relative current has been recorded at each timestep.

# %% [markdown]
# Let's first start loading the 2 files and check the shape and structure of the data.

# %%
polymer2 = np.load("../data/AA66266AA.npy",allow_pickle=True)
polymer22 = np.load("../data/AA662266AA.npy",allow_pickle=True)

# %%
polymer2.shape, polymer22.shape
# Out:
# ((22039,), (50957,))

# %% [markdown]
# Let's try to get a feel at how our data looks like

# %%
plot_data(polymer2[42:47])

# %%
plot_data(polymer22[42:47])

# %% [markdown]
# Although it can be a bit hard to interpret what really is going on with those plots, we see that :
# 1. The lengths of the events are far from constant
# 2. The relative current in the second dataset tends to be really lower
# 3. The current appears to be more "noisy" in the second datset than in the first

# %% [markdown]
# Let's first explore our first observation

# %%
polymer2_event_lens = [len(event) for event in polymer2]
polymer22_event_lens = [len(event) for event in polymer22]

# %%
fig, axes = plt.subplots(1, 2, figsize=(30, 10))
for ax, event_lens, ptype in zip(axes, [polymer2_event_lens, polymer22_event_lens], [2, 22]):
    ax.set_xlabel(f'polymer-{ptype} event length')
    sns.histplot(event_lens, ax=ax, log_scale=True)

# %%
np.mean(polymer2_event_lens),np.mean(polymer22_event_lens)
# Out:
# (506.773174826444, 476.0215083305532)

# %%
np.std(polymer2_event_lens),np.mean(polymer22_event_lens)
# Out:
# (1272.5643340000602, 476.0215083305532)

# %% [markdown]
# Surprisingly, the longer sequence tends to pass through the nanopore a bit quicker on average, and follow more closely its expected value (so less polymers getting stuck or going too quick).

# %% [markdown]
# Let's now discuss our other 2 observations

# %%
polymer2_currents = np.concatenate([event[:, 1] for event in polymer2])
polymer22_currents = np.concatenate([event[:, 1] for event in polymer22])

# %%
fig, axes = plt.subplots(1, 2, figsize=(30, 10))
for ax, currents, ptype in zip(axes, [polymer2_currents, polymer22_currents], [2, 22]):
    ax.set_xlabel(f'polymer-{ptype} current')
    sns.histplot(currents, ax=ax)

# %%
np.mean(polymer2_currents),np.mean(polymer22_currents)
# Out:
# (33.589424, 24.884472)

# %%
np.std(polymer2_currents),np.std(polymer22_currents)
# Out:
# (12.18849, 15.973785)

# %% [markdown]
# It appears that our 2nd and 3rd observations were both correct, the longer sequences (with more bulky elements) tend to have a bigger standard deviation. This makes sense as the pore will be obstructed for longer, and thus have a lower relative current far from it's baseline mean, for longer.
# We also see a little bump in the distribution of current around 0% for the shorter sequences. This could be explained as saturation in the sensor.
# There seems to be also more outlier on the right side of the distribution for the short sequence, but it is hard to make sense of it now.

# %% [markdown]
# Using what we've seen so far, let's try computing some very basic statistics for each dataset and see wether or not they would make great features

# %%
polymer_currents = [polymer2_currents, polymer22_currents]
polymers = [2, 22]
stats = ['mean', 'median', 'std', 'min', 'max']
polymer_stats = pd.DataFrame({
    'polymer': np.concatenate([[p] * len(stats) for p in polymers]),
    'stat': stats * len(polymers),
    'value': np.concatenate([[np.mean(currents), np.median(currents), np.std(currents), np.min(currents), np.max(currents)] for currents in polymer_currents])
})

# %%
sns.barplot(data=polymer_stats, x='stat', y='value', hue='polymer')
# Out:
# <AxesSubplot:xlabel='stat', ylabel='value'>

# %% [markdown]
# As predicted, the lower current values could really help telling apart our polymers

# %% [markdown]
# ## Feature Engineering and Data Preprocessing
# For detailed explanations and great vizualisations of what we're doing here, please report to ../multi-class/polymer-245.ipynb

# %% [markdown]
# ## Modelling

# %%
pipe = PairSingle_Pipeline(num_blocks=6)
dataset_fft = PolymerDataset(data_paths=["../data/AA66266AA.npy","../data/AA662266AA.npy"],pipeline=pipe)
# Out:
# Processing ../data/AA66266AA.npy: 100%|██████████| 17594/17594 [00:56<00:00, 311.32it/s]
# Processing ../data/AA662266AA.npy: 100%|██████████| 17625/17625 [00:45<00:00, 385.52it/s]

# %%
train_data, test_data = train_test_split(dataset_fft)

# %%
model = PReLULSTM(input_dim=dataset_fft.num_features, output_dim=dataset_fft.num_classes, num_layers=1, hidden_dim=64)

# %%
model, test_metrics = train(train_data, model, batch_size=512, num_epochs=150, lr_rate=0.005, test_dataset=test_data)
# Out:
# 2021-12-22 16:33:22.784384: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2021-12-22 16:33:22.784402: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
#                     Syncing run <strong><a href="https://wandb.ai/lucastrg/ml4science-polymers/runs/32wao09e" target="_blank">giddy-butterfly-79</a></strong> to <a href="https://wandb.ai/lucastrg/ml4science-polymers" target="_blank">Weights & Biases</a> (<a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">docs</a>).<br/>
# epoch=0/150, loss=0.689949, accuracy=52.0940
# epoch=0/150, test_accuracy=63.3679
# epoch=1/150, loss=0.678486, accuracy=65.6552
# epoch=1/150, test_accuracy=67.3719
# epoch=2/150, loss=0.662391, accuracy=68.2105
# epoch=2/150, test_accuracy=68.4651
# epoch=3/150, loss=0.639425, accuracy=69.8751
# epoch=3/150, test_accuracy=70.5097
# epoch=4/150, loss=0.604542, accuracy=72.3027
# epoch=4/150, test_accuracy=74.0168
# epoch=5/150, loss=0.556842, accuracy=76.0009
# epoch=5/150, test_accuracy=78.1627
# epoch=6/150, loss=0.497663, accuracy=80.0539
# epoch=6/150, test_accuracy=81.4994
# epoch=7/150, loss=0.435446, accuracy=82.4461
# epoch=7/150, test_accuracy=83.3594
# epoch=8/150, loss=0.388119, accuracy=83.6989
# epoch=8/150, test_accuracy=83.9983
# epoch=9/150, loss=0.356624, accuracy=84.8098
# epoch=9/150, test_accuracy=85.0064
# epoch=10/150, loss=0.327215, accuracy=85.7893
# epoch=10/150, test_accuracy=85.8867
# epoch=11/150, loss=0.309418, accuracy=86.5453
# epoch=11/150, test_accuracy=86.5540
# epoch=12/150, loss=0.291109, accuracy=87.2835
# epoch=12/150, test_accuracy=87.1220
# epoch=13/150, loss=0.279303, accuracy=87.8407
# epoch=13/150, test_accuracy=87.5763
# epoch=14/150, loss=0.269871, accuracy=88.3589
# epoch=14/150, test_accuracy=88.0875
# epoch=15/150, loss=0.270718, accuracy=88.6890
# epoch=15/150, test_accuracy=88.3146
# epoch=16/150, loss=0.254964, accuracy=89.1858
# epoch=16/150, test_accuracy=88.6980
# epoch=17/150, loss=0.254923, accuracy=89.3101
# epoch=17/150, test_accuracy=88.9394
# epoch=18/150, loss=0.248102, accuracy=89.5585
# epoch=18/150, test_accuracy=89.1098
# epoch=19/150, loss=0.244456, accuracy=89.7963
# epoch=19/150, test_accuracy=89.4079
# epoch=20/150, loss=0.241729, accuracy=89.9347
# epoch=20/150, test_accuracy=89.4647
# epoch=21/150, loss=0.237066, accuracy=90.0447
# epoch=21/150, test_accuracy=89.6777
# epoch=22/150, loss=0.235427, accuracy=90.1760
# epoch=22/150, test_accuracy=89.7345
# epoch=23/150, loss=0.230167, accuracy=90.2577
# epoch=23/150, test_accuracy=89.8197
# epoch=24/150, loss=0.229191, accuracy=90.4529
# epoch=24/150, test_accuracy=90.0611
# epoch=25/150, loss=0.232317, accuracy=90.4884
# epoch=25/150, test_accuracy=90.0895
# epoch=26/150, loss=0.225143, accuracy=90.6374
# epoch=26/150, test_accuracy=90.1178
# epoch=27/150, loss=0.220674, accuracy=90.8078
# epoch=27/150, test_accuracy=90.3450
# epoch=28/150, loss=0.219263, accuracy=90.9462
# epoch=28/150, test_accuracy=90.4870
# epoch=29/150, loss=0.218180, accuracy=91.0491
# epoch=29/150, test_accuracy=90.6148
# epoch=30/150, loss=0.216639, accuracy=91.1414
# epoch=30/150, test_accuracy=90.6858
# epoch=31/150, loss=0.212338, accuracy=91.2976
# epoch=31/150, test_accuracy=90.8278
# epoch=32/150, loss=0.207552, accuracy=91.4573
# epoch=32/150, test_accuracy=90.9840
# epoch=33/150, loss=0.205188, accuracy=91.5389
# epoch=33/150, test_accuracy=91.0124
# epoch=34/150, loss=0.208369, accuracy=91.6418
# epoch=34/150, test_accuracy=91.2679
# epoch=35/150, loss=0.204184, accuracy=91.7518
# epoch=35/150, test_accuracy=91.4383
# epoch=36/150, loss=0.201914, accuracy=91.7731
# epoch=36/150, test_accuracy=91.4525
# epoch=37/150, loss=0.198496, accuracy=91.9080
# epoch=37/150, test_accuracy=91.5661
# epoch=38/150, loss=0.200219, accuracy=91.9896
# epoch=38/150, test_accuracy=91.7223
# epoch=39/150, loss=0.199132, accuracy=92.0677
# epoch=39/150, test_accuracy=91.6087
# epoch=40/150, loss=0.192108, accuracy=92.2274
# epoch=40/150, test_accuracy=91.8217
# epoch=41/150, loss=0.193609, accuracy=92.2274
# epoch=41/150, test_accuracy=91.8501
# epoch=42/150, loss=0.190831, accuracy=92.3481
# epoch=42/150, test_accuracy=91.9920
# epoch=43/150, loss=0.186479, accuracy=92.3978
# epoch=43/150, test_accuracy=92.1056
# epoch=44/150, loss=0.184108, accuracy=92.5397
# epoch=44/150, test_accuracy=92.0346
# epoch=45/150, loss=0.182357, accuracy=92.5007
# epoch=45/150, test_accuracy=92.2192
# epoch=46/150, loss=0.181170, accuracy=92.6001
# epoch=46/150, test_accuracy=92.2050
# epoch=47/150, loss=0.179659, accuracy=92.7101
# epoch=47/150, test_accuracy=92.3186
# epoch=48/150, loss=0.181073, accuracy=92.7917
# epoch=48/150, test_accuracy=92.3470
# epoch=49/150, loss=0.178447, accuracy=92.8663
# epoch=49/150, test_accuracy=92.3612
# epoch=50/150, loss=0.177046, accuracy=92.8982
# epoch=50/150, test_accuracy=92.4180
# epoch=51/150, loss=0.176097, accuracy=92.9514
# epoch=51/150, test_accuracy=92.4890
# epoch=52/150, loss=0.177707, accuracy=93.0366
# epoch=52/150, test_accuracy=92.4606
# epoch=53/150, loss=0.176955, accuracy=93.1112
# epoch=53/150, test_accuracy=92.5032
# epoch=54/150, loss=0.175603, accuracy=93.0686
# epoch=54/150, test_accuracy=92.5032
# epoch=55/150, loss=0.172111, accuracy=93.1395
# epoch=55/150, test_accuracy=92.6452
# epoch=56/150, loss=0.171873, accuracy=93.2141
# epoch=56/150, test_accuracy=92.5742
# epoch=57/150, loss=0.171677, accuracy=93.2496
# epoch=57/150, test_accuracy=92.6736
# epoch=58/150, loss=0.168873, accuracy=93.2744
# epoch=58/150, test_accuracy=92.8014
# epoch=59/150, loss=0.168699, accuracy=93.2886
# epoch=59/150, test_accuracy=92.8014
# epoch=60/150, loss=0.171683, accuracy=93.3596
# epoch=60/150, test_accuracy=92.7872
# epoch=61/150, loss=0.168131, accuracy=93.3880
# epoch=61/150, test_accuracy=92.8014
# epoch=62/150, loss=0.172313, accuracy=93.3880
# epoch=62/150, test_accuracy=92.9008
# epoch=63/150, loss=0.167303, accuracy=93.4057
# epoch=63/150, test_accuracy=92.9150
# epoch=64/150, loss=0.164181, accuracy=93.4803
# epoch=64/150, test_accuracy=92.9717
# epoch=65/150, loss=0.166514, accuracy=93.4874
# epoch=65/150, test_accuracy=93.1137
# epoch=66/150, loss=0.165230, accuracy=93.4696
# epoch=66/150, test_accuracy=92.8866
# epoch=67/150, loss=0.162161, accuracy=93.5300
# epoch=67/150, test_accuracy=92.9433
# epoch=68/150, loss=0.161408, accuracy=93.5406
# epoch=68/150, test_accuracy=93.2983
# epoch=69/150, loss=0.163105, accuracy=93.5477
# epoch=69/150, test_accuracy=93.1563
# epoch=70/150, loss=0.160231, accuracy=93.5796
# epoch=70/150, test_accuracy=93.1847
# epoch=71/150, loss=0.162016, accuracy=93.5654
# epoch=71/150, test_accuracy=93.1989
# epoch=72/150, loss=0.160275, accuracy=93.6045
# epoch=72/150, test_accuracy=93.2273
# epoch=73/150, loss=0.161092, accuracy=93.6258
# epoch=73/150, test_accuracy=93.3267
# epoch=74/150, loss=0.159267, accuracy=93.6329
# epoch=74/150, test_accuracy=93.3125
# epoch=75/150, loss=0.160308, accuracy=93.6755
# epoch=75/150, test_accuracy=93.2273
# epoch=76/150, loss=0.161101, accuracy=93.6719
# epoch=76/150, test_accuracy=93.1847
# epoch=77/150, loss=0.158271, accuracy=93.7500
# epoch=77/150, test_accuracy=93.4119
# epoch=78/150, loss=0.158758, accuracy=93.6968
# epoch=78/150, test_accuracy=93.3835
# epoch=79/150, loss=0.157828, accuracy=93.7145
# epoch=79/150, test_accuracy=93.4119
# epoch=80/150, loss=0.160319, accuracy=93.7393
# epoch=80/150, test_accuracy=93.3977
# epoch=81/150, loss=0.154856, accuracy=93.7926
# epoch=81/150, test_accuracy=93.4545
# epoch=82/150, loss=0.154396, accuracy=93.7677
# epoch=82/150, test_accuracy=93.3693
# epoch=83/150, loss=0.158374, accuracy=93.7819
# epoch=83/150, test_accuracy=93.4119
# epoch=84/150, loss=0.161269, accuracy=93.7997
# epoch=84/150, test_accuracy=93.3551
# epoch=85/150, loss=0.155065, accuracy=93.7784
# epoch=85/150, test_accuracy=93.3977
# epoch=86/150, loss=0.154930, accuracy=93.8174
# epoch=86/150, test_accuracy=93.4119
# epoch=87/150, loss=0.157862, accuracy=93.8565
# epoch=87/150, test_accuracy=93.3693
# epoch=88/150, loss=0.155807, accuracy=93.9062
# epoch=88/150, test_accuracy=93.4545
# epoch=89/150, loss=0.153118, accuracy=93.8600
# epoch=89/150, test_accuracy=93.4545
# epoch=90/150, loss=0.158699, accuracy=93.9239
# epoch=90/150, test_accuracy=93.3267
# epoch=91/150, loss=0.155648, accuracy=93.9204
# epoch=91/150, test_accuracy=93.4829
# epoch=92/150, loss=0.152496, accuracy=93.8742
# epoch=92/150, test_accuracy=93.5539
# epoch=93/150, loss=0.151357, accuracy=93.9594
# epoch=93/150, test_accuracy=93.5823
# epoch=94/150, loss=0.157599, accuracy=93.9310
# epoch=94/150, test_accuracy=93.5255
# epoch=95/150, loss=0.151536, accuracy=93.9452
# epoch=95/150, test_accuracy=93.5397
# epoch=96/150, loss=0.151033, accuracy=94.0020
# epoch=96/150, test_accuracy=93.4829
# epoch=97/150, loss=0.153245, accuracy=93.9736
# epoch=97/150, test_accuracy=93.4829
# epoch=98/150, loss=0.152982, accuracy=93.9204
# epoch=98/150, test_accuracy=93.5113
# epoch=99/150, loss=0.149827, accuracy=94.0055
# epoch=99/150, test_accuracy=93.5965
# epoch=100/150, loss=0.149217, accuracy=93.9771
# epoch=100/150, test_accuracy=93.5397
# epoch=101/150, loss=0.149168, accuracy=94.0055
# epoch=101/150, test_accuracy=93.5113
# epoch=102/150, loss=0.150732, accuracy=94.0268
# epoch=102/150, test_accuracy=93.3835
# epoch=103/150, loss=0.149604, accuracy=94.0659
# epoch=103/150, test_accuracy=93.6391
# epoch=104/150, loss=0.151217, accuracy=94.0481
# epoch=104/150, test_accuracy=93.6107
# epoch=105/150, loss=0.149187, accuracy=94.0304
# epoch=105/150, test_accuracy=93.6675
# epoch=106/150, loss=0.148787, accuracy=94.0410
# epoch=106/150, test_accuracy=93.6533
# epoch=107/150, loss=0.150853, accuracy=94.0375
# epoch=107/150, test_accuracy=93.6107
# epoch=108/150, loss=0.147846, accuracy=94.1049
# epoch=108/150, test_accuracy=93.6675
# epoch=109/150, loss=0.148323, accuracy=94.0943
# epoch=109/150, test_accuracy=93.6249
# epoch=110/150, loss=0.150673, accuracy=94.0872
# epoch=110/150, test_accuracy=93.7669
# epoch=111/150, loss=0.148480, accuracy=94.1049
# epoch=111/150, test_accuracy=93.7385
# epoch=112/150, loss=0.148137, accuracy=94.1262
# epoch=112/150, test_accuracy=93.6107
# epoch=113/150, loss=0.147724, accuracy=94.0659
# epoch=113/150, test_accuracy=93.8095
# epoch=114/150, loss=0.146340, accuracy=94.0907
# epoch=114/150, test_accuracy=93.7811
# epoch=115/150, loss=0.146561, accuracy=94.1404
# epoch=115/150, test_accuracy=93.8237
# epoch=116/150, loss=0.146951, accuracy=94.1510
# epoch=116/150, test_accuracy=93.6675
# epoch=117/150, loss=0.147558, accuracy=94.1333
# epoch=117/150, test_accuracy=93.8095
# epoch=118/150, loss=0.149310, accuracy=94.1404
# epoch=118/150, test_accuracy=93.8521
# epoch=119/150, loss=0.147776, accuracy=94.1652
# epoch=119/150, test_accuracy=93.8663
# epoch=120/150, loss=0.146551, accuracy=94.1901
# epoch=120/150, test_accuracy=93.9230
# epoch=121/150, loss=0.144766, accuracy=94.1936
# epoch=121/150, test_accuracy=93.8095
# epoch=122/150, loss=0.144053, accuracy=94.1617
# epoch=122/150, test_accuracy=93.8095
# epoch=123/150, loss=0.146390, accuracy=94.2043
# epoch=123/150, test_accuracy=93.8379
# epoch=124/150, loss=0.146029, accuracy=94.2149
# epoch=124/150, test_accuracy=93.8379
# epoch=125/150, loss=0.144874, accuracy=94.2220
# epoch=125/150, test_accuracy=93.8946
# epoch=126/150, loss=0.143472, accuracy=94.2327
# epoch=126/150, test_accuracy=93.9940
# epoch=127/150, loss=0.143310, accuracy=94.1865
# epoch=127/150, test_accuracy=93.9656
# epoch=128/150, loss=0.147639, accuracy=94.2504
# epoch=128/150, test_accuracy=93.9372
# epoch=129/150, loss=0.145465, accuracy=94.2291
# epoch=129/150, test_accuracy=93.7243
# epoch=130/150, loss=0.146258, accuracy=94.3001
# epoch=130/150, test_accuracy=93.7385
# epoch=131/150, loss=0.143526, accuracy=94.2327
# epoch=131/150, test_accuracy=94.0366
# epoch=132/150, loss=0.148220, accuracy=94.2504
# epoch=132/150, test_accuracy=94.0366
# epoch=133/150, loss=0.145642, accuracy=94.2753
# epoch=133/150, test_accuracy=93.9656
# epoch=134/150, loss=0.144369, accuracy=94.2043
# epoch=134/150, test_accuracy=94.0650
# epoch=135/150, loss=0.143516, accuracy=94.3285
# epoch=135/150, test_accuracy=93.9940
# epoch=136/150, loss=0.145314, accuracy=94.2220
# epoch=136/150, test_accuracy=93.8095
# epoch=137/150, loss=0.144151, accuracy=94.1865
# epoch=137/150, test_accuracy=94.1076
# epoch=138/150, loss=0.147968, accuracy=94.2611
# epoch=138/150, test_accuracy=94.0508
# epoch=139/150, loss=0.144847, accuracy=94.3250
# epoch=139/150, test_accuracy=93.9514
# epoch=140/150, loss=0.145671, accuracy=94.2469
# epoch=140/150, test_accuracy=94.0224
# epoch=141/150, loss=0.145078, accuracy=94.2149
# epoch=141/150, test_accuracy=93.9940
# epoch=142/150, loss=0.141892, accuracy=94.2575
# epoch=142/150, test_accuracy=94.0508
# epoch=143/150, loss=0.140783, accuracy=94.2788
# epoch=143/150, test_accuracy=94.1076
# epoch=144/150, loss=0.141285, accuracy=94.2966
# epoch=144/150, test_accuracy=94.1218
# epoch=145/150, loss=0.142383, accuracy=94.3108
# epoch=145/150, test_accuracy=94.0224
# epoch=146/150, loss=0.142265, accuracy=94.3108
# epoch=146/150, test_accuracy=94.0508
# epoch=147/150, loss=0.141524, accuracy=94.3463
# epoch=147/150, test_accuracy=94.0934
# epoch=148/150, loss=0.145904, accuracy=94.3214
# epoch=148/150, test_accuracy=94.1786
# epoch=149/150, loss=0.143766, accuracy=94.3675
# epoch=149/150, test_accuracy=94.0650
# Waiting for W&B process to finish, PID 418146... <strong style="color:green">(success).</strong>
# Synced <strong style="color:#cdcd00">giddy-butterfly-79</strong>: <a href="https://wandb.ai/lucastrg/ml4science-polymers/runs/32wao09e" target="_blank">https://wandb.ai/lucastrg/ml4science-polymers/runs/32wao09e</a><br/>

# %%
test(test_data,model=model)
# Out:
# {'accuracy': 0.9406502910691467,
#  'f1_score': 0.940625,
#  'precision': 0.9430361720307605,
#  'recall': 0.9382261263814111,
#  'confusion_matrix': array([[0.943, 0.057],
#         [0.062, 0.938]])}

# %%
np.save(arr=dataset_fft.labels.numpy(),file="backbone_bulky4_labels")

# %%
def kfold_cv_iter(y: np.ndarray, tx: np.ndarray, k: int = 5, seed: float = 1):
    """K-fold cross validation. Split data into k parts and iterate through the folds
    Args:
        y (np.ndarray): Label data
        tx (np.ndarray): Features data
        k (int, optional): Number of folds. Defaults to 5.
        seed (float, optional): Seed for randomization. Defaults to 1.
    Yields:
        Generator: (x_train, y_train, x_test, y_test)
    """
    num_row = y.shape[0]
    fold_size = int(num_row / k)
    np.random.seed(seed)
    indices = np.random.permutation(num_row)
    
    for i in range(k):
        test_indices = indices[i * fold_size: (i + 1) * fold_size]
        train_indices = list(set(range(num_row)) - set(test_indices))
        yield tx[train_indices], y[train_indices], tx[test_indices], y[test_indices]

# %%
def train_random_forest(x,y, k=5, n_estimators = 100):
    accuracies = []
    importances = []

    iter = kfold_cv_iter(y=y,tx=tx,k=k,seed=2)
    for X_train, Y_train, X_test, Y_test in iter:
        classifier = RandomForestClassifier(random_state=89,n_estimators = n_estimators )
        classifier.fit(X_train, Y_train)
        y_pred = classifier.predict(X_test)
        accuracy = accuracy_score(Y_test, y_pred)
        accuracies.append(accuracy)
        importances.append(classifier.feature_importances_)

    accuracies = np.array(accuracies)
    importances = np.array(importances)
    
    return accuracies, importances, classifier

# %%
y = dataset_fft.labels.numpy()
tx = dataset_fft.data.numpy()
tx = tx.reshape((tx.shape[0],-1))
forest = train_random_forest(x=tx,y=y,k=5,n_estimators=100)

# %%
def plot_feature_importances(feature_importances, names, num_blocks,title, savepath=None):

    df = pd.DataFrame()
    df['names'] = pd.Series(names*num_blocks)
    df['features'] = pd.Series(feature_importances)
    df['block_number'] = pd.Series([i  for i in range(1,num_blocks+1) for j in range(len(names))]) 

    f,a = plt.subplots(1,1,figsize=(30,15))
    g= sns.barplot(x='names', y='features', data=df, hue='block_number')
    g.set_title(title)
    g.set_xlabel("Feature names")
    g.set_ylabel("Feature importance")

    if savepath:
        plt.savefig(savepath, dpi=300)

# %%
features = forest[1].mean(axis=0)
names = ["mean", "median", "std", "min", "max", "len", "count_extremums", "max_slope", "min_slope","duration","max_amp","min_amp",
        "mean_amp",
        "std_amp",
        "dwell_time",
        "dwell_start",
        "dwell_end",
        "main_frequency",
        "secondary_frequency",
        "tertiary_frequency"]

# %%
plot_feature_importances(np.mean(forest[1], axis=0), names ,5, "Feature importance for the 20 feature model")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_20300/2059982901.py in <module>
# ----> 1 plot_feature_importances(np.mean(forest[1], axis=0), names ,5, "Feature importance for the 20 feature model")
#
# NameError: name 'plot_feature_importances' is not defined
