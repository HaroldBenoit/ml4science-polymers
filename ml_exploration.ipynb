# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
import statsmodels.formula.api as smf

# %matplotlib inline 

plt.style.use('ggplot')
plt.rcParams['figure.figsize'] = (15,7)

# %%
arr = np.load("AA00400AA.npy",allow_pickle=True)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13412/1585309285.py in <module>
# ----> 1 arr = np.load("AA00400AA.npy",allow_pickle=True)
#
# ~\anaconda3\lib\site-packages\numpy\lib\npyio.py in load(file, mmap_mode, allow_pickle, fix_imports, encoding)
#     415             own_fid = False
#     416         else:
# --> 417             fid = stack.enter_context(open(os_fspath(file), "rb"))
#     418             own_fid = True
#     419
#
# FileNotFoundError: [Errno 2] No such file or directory: 'AA00400AA.npy'

# %%
np.shape(arr[0][0])
# Out:
# (2,)

# %%
k = 15
fig, axes = plt.subplots(k,1, figsize=(15,15), sharex=True, sharey=True)

for i in range(k):
    obs = arr[i]
    time = obs[:,0]
    current = obs[:,1]

    g= sns.lineplot(x=time,y=current, ax=axes[i])
    g.set_xlabel("Time [ms]")
