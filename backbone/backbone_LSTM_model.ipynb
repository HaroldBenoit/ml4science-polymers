# %% [markdown]
# # LSTM models Notebook
#
# In this notebook, we implement LSTM models to differentiate two different backbones.

# %%
# %load_ext autoreload
# %autoreload 2


## classic pydata stack
import os 
import numpy as np
from tqdm import tqdm
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
import statsmodels.formula.api as smf

# %matplotlib inline 

plt.style.use('ggplot')
plt.rcParams['figure.figsize'] = (15,7)



## torch
import torch
from torch.utils.data import Dataset
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

## SEEDING
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import sys
sys.path.append('..')
from pipeline import *
from models import *

# %%
pipe3 = AA0066_Pipeline(num_blocks=3)
dataset3 = PolymerDataset(data_paths=["AA00400AA.npy","AA66466AA.npy"],pipeline=pipe3)
# Out:
# Processing AA00400AA.npy: 100%|██████████| 14162/14162 [00:45<00:00, 308.34it/s]
# Processing AA66466AA.npy: 100%|██████████| 14185/14185 [01:41<00:00, 139.52it/s]

# %%
train_data3, test_data3 = train_test_split(dataset3)

# %% [markdown]
# ### Leaky Relu LSTM

# %%
model = LeakyReluLSTM(input_dim=dataset3.num_features, output_dim=dataset3.num_classes, hidden_dim=64)
model, test_metrics = train(train_dataset = train_data3, test_dataset = test_data3, model=model, batch_size=512, num_epochs=100, lr_rate=0.01,verbose=2, log=False)
# Out:
# epoch=0/100, loss=0.27301207813951706, accuracy=88.34994506835938
# epoch=1/100, loss=0.15561555690235562, accuracy=93.59291076660156
# epoch=2/100, loss=0.13936342315541372, accuracy=94.28520965576172
# epoch=3/100, loss=0.12737100041574903, accuracy=94.68647766113281
# epoch=4/100, loss=0.1310902660091718, accuracy=94.69088745117188
# epoch=5/100, loss=0.12467977404594421, accuracy=94.88050079345703
# epoch=6/100, loss=0.12331853922870424, accuracy=94.986328125
# epoch=7/100, loss=0.12011118630568186, accuracy=94.9422378540039
# epoch=8/100, loss=0.11666261106729507, accuracy=95.22003936767578
# epoch=9/100, loss=0.11618759665224287, accuracy=95.23326873779297
# epoch=10/100, loss=0.11773521569040087, accuracy=95.05247497558594
# epoch=11/100, loss=0.11831288420491748, accuracy=95.1362533569336
# epoch=12/100, loss=0.11721382174226973, accuracy=95.16271209716797
# epoch=13/100, loss=0.11611947235133913, accuracy=95.10538482666016
# epoch=14/100, loss=0.11539284918043348, accuracy=95.24649810791016
# epoch=15/100, loss=0.11221462372276518, accuracy=95.35673522949219
# epoch=16/100, loss=0.11400546878576279, accuracy=95.3082275390625
# epoch=17/100, loss=0.11303410480419794, accuracy=95.35232543945312
# epoch=18/100, loss=0.11252775424056582, accuracy=95.31704711914062
# epoch=19/100, loss=0.11198789444234636, accuracy=95.37437438964844
# epoch=20/100, loss=0.11594457940922843, accuracy=95.17594146728516
# epoch=21/100, loss=0.11181407239702013, accuracy=95.43610382080078
# epoch=22/100, loss=0.11175059676170349, accuracy=95.40082550048828
# epoch=23/100, loss=0.11200321614742278, accuracy=95.29058837890625
# epoch=24/100, loss=0.10875926812489828, accuracy=95.45374298095703
# epoch=25/100, loss=0.10808016492260827, accuracy=95.5287094116211
# epoch=26/100, loss=0.11273588024907642, accuracy=95.35673522949219
# epoch=27/100, loss=0.11652965794006984, accuracy=95.19799041748047
# epoch=28/100, loss=0.1082848467760616, accuracy=95.61689758300781
# epoch=29/100, loss=0.11182207266489665, accuracy=95.38319396972656
# epoch=30/100, loss=0.1126127529475424, accuracy=95.26853942871094
# epoch=31/100, loss=0.10897825178172853, accuracy=95.5154800415039
# epoch=32/100, loss=0.10863209979401695, accuracy=95.44933319091797
# epoch=33/100, loss=0.10916958169804679, accuracy=95.47579193115234
# epoch=34/100, loss=0.10832206341955397, accuracy=95.47579193115234
# epoch=35/100, loss=0.11279523803128136, accuracy=95.30381774902344
# epoch=36/100, loss=0.10677486078606711, accuracy=95.47138214111328
# epoch=37/100, loss=0.1092469739417235, accuracy=95.32586669921875
# epoch=38/100, loss=0.10987305326594246, accuracy=95.3787841796875
# epoch=39/100, loss=0.10736303180456161, accuracy=95.38760375976562
# epoch=40/100, loss=0.10766278985473844, accuracy=95.53752899169922
# epoch=41/100, loss=0.10523410356707043, accuracy=95.60807800292969
# epoch=42/100, loss=0.10444396783908208, accuracy=95.61689758300781
# epoch=43/100, loss=0.10562009248468611, accuracy=95.63453674316406
# epoch=44/100, loss=0.10785030739174949, accuracy=95.59925842285156
# epoch=45/100, loss=0.10902472833792369, accuracy=95.50225067138672
# epoch=46/100, loss=0.10732910550302929, accuracy=95.5595703125
# epoch=47/100, loss=0.10626990695794424, accuracy=95.5595703125
# epoch=48/100, loss=0.10776625573635101, accuracy=95.63894653320312
# epoch=49/100, loss=0.10756542219056023, accuracy=95.64776611328125
# epoch=50/100, loss=0.10922016186846627, accuracy=95.47579193115234
# epoch=51/100, loss=0.10589399288098017, accuracy=95.58602905273438
# epoch=52/100, loss=0.10451283272769717, accuracy=95.57720947265625
# epoch=53/100, loss=0.10697339756621255, accuracy=95.48461151123047
# epoch=54/100, loss=0.10523701161146164, accuracy=95.59925842285156
# epoch=55/100, loss=0.10808069904645284, accuracy=95.53752899169922
# epoch=56/100, loss=0.10781732284360462, accuracy=95.58602905273438
# epoch=57/100, loss=0.10810687591632208, accuracy=95.57720947265625
# epoch=58/100, loss=0.10510329587592018, accuracy=95.56398010253906
# epoch=59/100, loss=0.10214310172531339, accuracy=95.8153305053711
# epoch=60/100, loss=0.10188111811876296, accuracy=95.67422485351562
# epoch=61/100, loss=0.10706772423452801, accuracy=95.68304443359375
# epoch=62/100, loss=0.10398746977249781, accuracy=95.65217590332031
# epoch=63/100, loss=0.10412257115046183, accuracy=95.72713470458984
# epoch=64/100, loss=0.10468837370475133, accuracy=95.58602905273438
# epoch=65/100, loss=0.10624547501405081, accuracy=95.55075073242188
# epoch=66/100, loss=0.10671977235211266, accuracy=95.5287094116211
# epoch=67/100, loss=0.10302559302912818, accuracy=95.65658569335938
# epoch=68/100, loss=0.10152268012364705, accuracy=95.72272491455078
# epoch=69/100, loss=0.10083335894677374, accuracy=95.7315444946289
# epoch=70/100, loss=0.1050273209810257, accuracy=95.66981506347656
# epoch=71/100, loss=0.10217768748601277, accuracy=95.68744659423828
# epoch=72/100, loss=0.10338887191481061, accuracy=95.68304443359375
# epoch=73/100, loss=0.10798930724461873, accuracy=95.5287094116211
# epoch=74/100, loss=0.10414000749588012, accuracy=95.70508575439453
# epoch=75/100, loss=0.1031503978702757, accuracy=95.64776611328125
# epoch=76/100, loss=0.1025017218457328, accuracy=95.83737182617188
# epoch=77/100, loss=0.10268984768125745, accuracy=95.63894653320312
# epoch=78/100, loss=0.10576308584875531, accuracy=95.53752899169922
# epoch=79/100, loss=0.10221742077006234, accuracy=95.78887176513672
# epoch=80/100, loss=0.10138967335224151, accuracy=95.70508575439453
# epoch=81/100, loss=0.10295923054218292, accuracy=95.59043884277344
# epoch=82/100, loss=0.10160333530770407, accuracy=95.79328155517578
# epoch=83/100, loss=0.1033493901292483, accuracy=95.76241302490234
# epoch=84/100, loss=0.10358736349476708, accuracy=95.76241302490234
# epoch=85/100, loss=0.1061726912856102, accuracy=95.4228744506836
# epoch=86/100, loss=0.10200440072351032, accuracy=95.71831512451172
# epoch=87/100, loss=0.10122847110033036, accuracy=95.78446197509766
# epoch=88/100, loss=0.1026157569554117, accuracy=95.74036407470703
# epoch=89/100, loss=0.1059035088453028, accuracy=95.5595703125
# epoch=90/100, loss=0.10422884573539098, accuracy=95.72272491455078
# epoch=91/100, loss=0.10255621373653412, accuracy=95.67863464355469
# epoch=92/100, loss=0.1016908112499449, accuracy=95.8021011352539
# epoch=93/100, loss=0.1033658868736691, accuracy=95.75800323486328
# epoch=94/100, loss=0.10310347742504544, accuracy=95.8153305053711
# epoch=95/100, loss=0.10460838245020973, accuracy=95.69185638427734
# epoch=96/100, loss=0.1034334381421407, accuracy=95.71390533447266
# epoch=97/100, loss=0.10649587942494286, accuracy=95.5595703125
# epoch=98/100, loss=0.10119211160474353, accuracy=95.72713470458984
# epoch=99/100, loss=0.10414619545141855, accuracy=95.50666046142578

# %%
test_metrics
# Out:
# {'accuracy': 0.9532545422473099,
#  'f1_score': 0.952053555274109,
#  'precision': 0.9623262618873446,
#  'recall': 0.9419978517722879,
#  'confusion_matrix': array([[0.964, 0.036],
#         [0.058, 0.942]])}

# %% [markdown]
# ### Vanilla LSTM

# %%
model2 = VanillaLSTM(input_dim=dataset3.num_features, output_dim=dataset3.num_classes, hidden_dim=64)
model2, test_metrics2 = train(train_dataset = train_data3, test_dataset = test_data3, model=model2, batch_size=512, num_epochs=100, lr_rate=0.01,verbose=2,log=False)
# Out:
# epoch=0/100, loss=0.105826, accuracy=95.5993
# epoch=0/100, test_accuracy=95.0609
# epoch=1/100, loss=0.104416, accuracy=95.5419
# epoch=1/100, test_accuracy=95.4313
# epoch=2/100, loss=0.102956, accuracy=95.7668
# epoch=2/100, test_accuracy=95.7135
# epoch=3/100, loss=0.104752, accuracy=95.6874
# epoch=3/100, test_accuracy=95.1491
# epoch=4/100, loss=0.107160, accuracy=95.5904
# epoch=4/100, test_accuracy=95.3960
# epoch=5/100, loss=0.099907, accuracy=95.7492
# epoch=5/100, test_accuracy=95.5195
# epoch=6/100, loss=0.106348, accuracy=95.6257
# epoch=6/100, test_accuracy=95.4489
# epoch=7/100, loss=0.102913, accuracy=95.7580
# epoch=7/100, test_accuracy=95.3607
# epoch=8/100, loss=0.103333, accuracy=95.6213
# epoch=8/100, test_accuracy=95.4666
# epoch=9/100, loss=0.102769, accuracy=95.6301
# epoch=9/100, test_accuracy=95.5195
# epoch=10/100, loss=0.102964, accuracy=95.5948
# epoch=10/100, test_accuracy=95.5019
# epoch=11/100, loss=0.102976, accuracy=95.7404
# epoch=11/100, test_accuracy=95.4842
# epoch=12/100, loss=0.102631, accuracy=95.6874
# epoch=12/100, test_accuracy=95.2373
# epoch=13/100, loss=0.101507, accuracy=95.6345
# epoch=13/100, test_accuracy=95.5019
# epoch=14/100, loss=0.105012, accuracy=95.6610
# epoch=14/100, test_accuracy=95.4137
# epoch=15/100, loss=0.101370, accuracy=95.7801
# epoch=15/100, test_accuracy=95.4666
# epoch=16/100, loss=0.099591, accuracy=95.8065
# epoch=16/100, test_accuracy=95.3431
# epoch=17/100, loss=0.100123, accuracy=95.8506
# epoch=17/100, test_accuracy=95.4842
# epoch=18/100, loss=0.099457, accuracy=95.9256
# epoch=18/100, test_accuracy=95.5901
# epoch=19/100, loss=0.098970, accuracy=95.8506
# epoch=19/100, test_accuracy=95.6430
# epoch=20/100, loss=0.099840, accuracy=95.7227
# epoch=20/100, test_accuracy=95.1843
# epoch=21/100, loss=0.100879, accuracy=95.7624
# epoch=21/100, test_accuracy=95.4842
# epoch=22/100, loss=0.100466, accuracy=95.7580
# epoch=22/100, test_accuracy=95.3960
# epoch=23/100, loss=0.101211, accuracy=95.8197
# epoch=23/100, test_accuracy=95.5019
# epoch=24/100, loss=0.101030, accuracy=95.7756
# epoch=24/100, test_accuracy=95.0609
# epoch=25/100, loss=0.103159, accuracy=95.7271
# epoch=25/100, test_accuracy=95.5901
# epoch=26/100, loss=0.103311, accuracy=95.7095
# epoch=26/100, test_accuracy=95.6253
# epoch=27/100, loss=0.102084, accuracy=95.8021
# epoch=27/100, test_accuracy=95.4489
# epoch=28/100, loss=0.102870, accuracy=95.7448
# epoch=28/100, test_accuracy=95.3431
# epoch=29/100, loss=0.100260, accuracy=95.8374
# epoch=29/100, test_accuracy=95.4666
# epoch=30/100, loss=0.103416, accuracy=95.6874
# epoch=30/100, test_accuracy=95.4137
# epoch=31/100, loss=0.101387, accuracy=95.7051
# epoch=31/100, test_accuracy=95.5548
# epoch=32/100, loss=0.100979, accuracy=95.6654
# epoch=32/100, test_accuracy=95.4313
# epoch=33/100, loss=0.103668, accuracy=95.6654
# epoch=33/100, test_accuracy=94.5493
# epoch=34/100, loss=0.105472, accuracy=95.6654
# epoch=34/100, test_accuracy=94.8668
# epoch=35/100, loss=0.102176, accuracy=95.7712
# epoch=35/100, test_accuracy=95.6253
# epoch=36/100, loss=0.102771, accuracy=95.7227
# epoch=36/100, test_accuracy=95.4137
# epoch=37/100, loss=0.103594, accuracy=95.7139
# epoch=37/100, test_accuracy=95.5195
# epoch=38/100, loss=0.100381, accuracy=95.8197
# epoch=38/100, test_accuracy=95.2902
# epoch=39/100, loss=0.101408, accuracy=95.7271
# epoch=39/100, test_accuracy=95.3607
# epoch=40/100, loss=0.101103, accuracy=95.8462
# epoch=40/100, test_accuracy=95.1843
# epoch=41/100, loss=0.100959, accuracy=95.8374
# epoch=41/100, test_accuracy=95.3784
# epoch=42/100, loss=0.101235, accuracy=95.7315
# epoch=42/100, test_accuracy=95.4137
# epoch=43/100, loss=0.100860, accuracy=95.7580
# epoch=43/100, test_accuracy=95.5548
# epoch=44/100, loss=0.100499, accuracy=95.7801
# epoch=44/100, test_accuracy=95.2020
# epoch=45/100, loss=0.102333, accuracy=95.8330
# epoch=45/100, test_accuracy=95.3960
# epoch=46/100, loss=0.106483, accuracy=95.5419
# epoch=46/100, test_accuracy=95.1667
# epoch=47/100, loss=0.100883, accuracy=95.8021
# epoch=47/100, test_accuracy=95.6959
# epoch=48/100, loss=0.102175, accuracy=95.7051
# epoch=48/100, test_accuracy=95.1138
# epoch=49/100, loss=0.102325, accuracy=95.7668
# epoch=49/100, test_accuracy=95.3960
# epoch=50/100, loss=0.099743, accuracy=95.8021
# epoch=50/100, test_accuracy=95.4137
# epoch=51/100, loss=0.102165, accuracy=95.7580
# epoch=51/100, test_accuracy=95.6253
# epoch=52/100, loss=0.101926, accuracy=95.6963
# epoch=52/100, test_accuracy=95.4137
# epoch=53/100, loss=0.099426, accuracy=95.7933
# epoch=53/100, test_accuracy=95.7135
# epoch=54/100, loss=0.100507, accuracy=95.7404
# epoch=54/100, test_accuracy=95.5195
# epoch=55/100, loss=0.100190, accuracy=95.8418
# epoch=55/100, test_accuracy=95.6077
# epoch=56/100, loss=0.099506, accuracy=95.8859
# epoch=56/100, test_accuracy=95.7135
# epoch=57/100, loss=0.101153, accuracy=95.8021
# epoch=57/100, test_accuracy=95.6783
# epoch=58/100, loss=0.101125, accuracy=95.7580
# epoch=58/100, test_accuracy=95.6959
# epoch=59/100, loss=0.101921, accuracy=95.8330
# epoch=59/100, test_accuracy=95.5019
# epoch=60/100, loss=0.103639, accuracy=95.7139
# epoch=60/100, test_accuracy=95.6430
# epoch=61/100, loss=0.103551, accuracy=95.6610
# epoch=61/100, test_accuracy=95.4489
# epoch=62/100, loss=0.100475, accuracy=95.7271
# epoch=62/100, test_accuracy=95.5019
# epoch=63/100, loss=0.101633, accuracy=95.7271
# epoch=63/100, test_accuracy=95.3960
# epoch=64/100, loss=0.102337, accuracy=95.7492
# epoch=64/100, test_accuracy=95.5548
# epoch=65/100, loss=0.100963, accuracy=95.7183
# epoch=65/100, test_accuracy=95.5724
# epoch=66/100, loss=0.099621, accuracy=95.8815
# epoch=66/100, test_accuracy=95.2196
# epoch=67/100, loss=0.101179, accuracy=95.8153
# epoch=67/100, test_accuracy=95.3255
# epoch=68/100, loss=0.101099, accuracy=95.7933
# epoch=68/100, test_accuracy=95.6077
# epoch=69/100, loss=0.099522, accuracy=95.7183
# epoch=69/100, test_accuracy=94.9727
# epoch=70/100, loss=0.099536, accuracy=95.7183
# epoch=70/100, test_accuracy=95.3607
# epoch=71/100, loss=0.100628, accuracy=95.7580
# epoch=71/100, test_accuracy=95.2196
# epoch=72/100, loss=0.100705, accuracy=95.8065
# epoch=72/100, test_accuracy=95.6959
# epoch=73/100, loss=0.098974, accuracy=95.8418
# epoch=73/100, test_accuracy=95.6783
# epoch=74/100, loss=0.100609, accuracy=95.8815
# epoch=74/100, test_accuracy=95.6430
# epoch=75/100, loss=0.101852, accuracy=95.7007
# epoch=75/100, test_accuracy=95.5195
# epoch=76/100, loss=0.103040, accuracy=95.6742
# epoch=76/100, test_accuracy=95.4842
# epoch=77/100, loss=0.103208, accuracy=95.6213
# epoch=77/100, test_accuracy=95.1843
# epoch=78/100, loss=0.101471, accuracy=95.7448
# epoch=78/100, test_accuracy=95.4313
# epoch=79/100, loss=0.103558, accuracy=95.6169
# epoch=79/100, test_accuracy=95.4489
# epoch=80/100, loss=0.099859, accuracy=95.8462
# epoch=80/100, test_accuracy=95.4666
# epoch=81/100, loss=0.102342, accuracy=95.7492
# epoch=81/100, test_accuracy=95.4842
# epoch=82/100, loss=0.100103, accuracy=95.7977
# epoch=82/100, test_accuracy=95.4489
# epoch=83/100, loss=0.103959, accuracy=95.7536
# epoch=83/100, test_accuracy=95.6959
# epoch=84/100, loss=0.099510, accuracy=95.8197
# epoch=84/100, test_accuracy=95.7312
# epoch=85/100, loss=0.101646, accuracy=95.6654
# epoch=85/100, test_accuracy=95.4666
# epoch=86/100, loss=0.101234, accuracy=95.7536
# epoch=86/100, test_accuracy=95.6430
# epoch=87/100, loss=0.101461, accuracy=95.8109
# epoch=87/100, test_accuracy=95.1843
# epoch=88/100, loss=0.102809, accuracy=95.6874
# epoch=88/100, test_accuracy=95.2196
# epoch=89/100, loss=0.103650, accuracy=95.6257
# epoch=89/100, test_accuracy=95.3255
# epoch=90/100, loss=0.101229, accuracy=95.8815
# epoch=90/100, test_accuracy=95.5371
# epoch=91/100, loss=0.101051, accuracy=95.6830
# epoch=91/100, test_accuracy=95.3431
# epoch=92/100, loss=0.101662, accuracy=95.7315
# epoch=92/100, test_accuracy=95.5901
# epoch=93/100, loss=0.099818, accuracy=95.8506
# epoch=93/100, test_accuracy=95.4489
# epoch=94/100, loss=0.101518, accuracy=95.7845
# epoch=94/100, test_accuracy=95.3078
# epoch=95/100, loss=0.098611, accuracy=95.8065
# epoch=95/100, test_accuracy=95.4137
# epoch=96/100, loss=0.102729, accuracy=95.7668
# epoch=96/100, test_accuracy=95.5901
# epoch=97/100, loss=0.101517, accuracy=95.6963
# epoch=97/100, test_accuracy=95.2020
# epoch=98/100, loss=0.101370, accuracy=95.8727
# epoch=98/100, test_accuracy=95.7664
# epoch=99/100, loss=0.099296, accuracy=95.8462
# epoch=99/100, test_accuracy=95.3960
